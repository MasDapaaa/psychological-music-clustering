# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Load datasetnya
df = pd.read_csv("mxmh_survey_results.csv")

# %%
# Ambil kolom yang dibutuhkan
fitur = df[["BPM", "Anxiety", "Depression", "Insomnia", "Hours per day"]]

# %%
# Drop data yg kosong
fitur = fitur.dropna()

# %%
# Standardisasi data
scaler = StandardScaler()
fitur_scaled = scaler.fit_transform(fitur)

# %%
# Clustering K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(fitur_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Tambahkan label cluster ke data asli
fitur["Cluster"] = kmeans.labels_

# %%
# Visualisasi (pakai fitur Anxiety dan Depression)
plt.figure(figsize=(8, 6))
plt.scatter(fitur["Anxiety"], fitur["Depression"], c=fitur["Cluster"], cmap="viridis")
plt.xlabel("Anxiety")
plt.ylabel("Depression")
plt.title("K-Means Clustering: Musik vs Kesehatan Mental")
plt.colorbar(label="Cluster")
plt.grid(True)
plt.show()

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Generate data sintetis
X, _ = make_blobs(n_samples=1000, centers=3, cluster_std=0.8, random_state=42)

# %%
# Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
labels = kmeans.fit_predict(X)

# %%
# Visualisasi
plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow', s=20, edgecolor='k', alpha=0.6)
plt.title('Clustering Data Sintetis (K-Means)')
plt.xlabel('Fitur 1')
plt.ylabel('Fitur 2')
plt.grid(True)
plt.show()
